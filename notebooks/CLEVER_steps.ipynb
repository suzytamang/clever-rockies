# %% [markdown]
# ### Purpose of notebook:
#
# The purpose of this notebook is to automate the process of running the clever steps. Instead of manually having to run each clever step, you can run the cell blocks below.
#
# **Make sure you have the output directory created beforehand**

# %%
# Delete all subfolders from within the output directory. This is needed so that each run can start from a clean state.abs
import os
import shutil

OUTPUT_DIRECTORY = '../output202210'

for item in os.listdir(OUTPUT_DIRECTORY):
    item_path = os.path.join(OUTPUT_DIRECTORY, item)
    if os.path.isdir(item_path):
        shutil.rmtree(item_path)

# %%
# Step 2
# %time
# !bash ../src/step2/step2.sh
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11.2 µs
# Main targets not found - exitingstring index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range
# string index out of range

# %%
# Step 3
# !bash ../src/step3/step3.sh
# Out:
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/XYLA/extraction-7844.tsv
# LOADING FILE:  ../../output202210/XYLA/extraction-7845.tsv
# LOADING FILE:  ../../output202210/XYLA/extraction-7846.tsv
# LOADING FILE:  ../../output202210/XYLA/extraction-7847.tsv
# LOADING FILE:  ../../output202210/XYLA/extraction-7848.tsv
# LOADING FILE:  ../../output202210/XYLA/extraction-7849.tsv
# LOADING FILE:  ../../output202210/XYLA/extraction-7850.tsv
# LOADING FILE:  ../../output202210/XYLA/extraction-7851.tsv
# 11 total annotation for target terms
# Length of Sequence Dictionary: 11
# CANDIDATE EVENTS: 11
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/A2AG/extraction-7885.tsv
# LOADING FILE:  ../../output202210/A2AG/extraction-7886.tsv
# LOADING FILE:  ../../output202210/A2AG/extraction-7887.tsv
# LOADING FILE:  ../../output202210/A2AG/extraction-7888.tsv
# LOADING FILE:  ../../output202210/A2AG/extraction-7889.tsv
# LOADING FILE:  ../../output202210/A2AG/extraction-7890.tsv
# LOADING FILE:  ../../output202210/A2AG/extraction-7891.tsv
# LOADING FILE:  ../../output202210/A2AG/extraction-7892.tsv
# 254 total annotation for target terms
# Length of Sequence Dictionary: 254
# CANDIDATE EVENTS: 254
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/PDMP/extraction-7913.tsv
# LOADING FILE:  ../../output202210/PDMP/extraction-7914.tsv
# LOADING FILE:  ../../output202210/PDMP/extraction-7915.tsv
# LOADING FILE:  ../../output202210/PDMP/extraction-7916.tsv
# LOADING FILE:  ../../output202210/PDMP/extraction-7917.tsv
# LOADING FILE:  ../../output202210/PDMP/extraction-7918.tsv
# LOADING FILE:  ../../output202210/PDMP/extraction-7919.tsv
# LOADING FILE:  ../../output202210/PDMP/extraction-7920.tsv
# 1522 total annotation for target terms
# Length of Sequence Dictionary: 1522
# CANDIDATE EVENTS: 1522
# Total notes:  343079
# NOTES: 343079
# 0 total annotation for target terms
# Length of Sequence Dictionary: 0
# CANDIDATE EVENTS: 0
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7948.tsv
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7949.tsv
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7950.tsv
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7951.tsv
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7952.tsv
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7953.tsv
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7954.tsv
# LOADING FILE:  ../../output202210/BTRAITS/extraction-7955.tsv
# 143 total annotation for target terms
# Length of Sequence Dictionary: 143
# CANDIDATE EVENTS: 143
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/BDD/extraction-7967.tsv
# LOADING FILE:  ../../output202210/BDD/extraction-7968.tsv
# LOADING FILE:  ../../output202210/BDD/extraction-7969.tsv
# LOADING FILE:  ../../output202210/BDD/extraction-7970.tsv
# LOADING FILE:  ../../output202210/BDD/extraction-7971.tsv
# LOADING FILE:  ../../output202210/BDD/extraction-7972.tsv
# LOADING FILE:  ../../output202210/BDD/extraction-7973.tsv
# LOADING FILE:  ../../output202210/BDD/extraction-7974.tsv
# 4 total annotation for target terms
# Length of Sequence Dictionary: 4
# CANDIDATE EVENTS: 4
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7985.tsv
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7986.tsv
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7987.tsv
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7988.tsv
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7989.tsv
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7990.tsv
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7991.tsv
# LOADING FILE:  ../../output202210/GAMINGDO/extraction-7992.tsv
# 0 total annotation for target terms
# Length of Sequence Dictionary: 0
# CANDIDATE EVENTS: 0
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8013.tsv
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8014.tsv
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8015.tsv
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8016.tsv
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8017.tsv
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8018.tsv
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8019.tsv
# LOADING FILE:  ../../output202210/GAMBLINGDO/extraction-8020.tsv
# 93 total annotation for target terms
# Length of Sequence Dictionary: 93
# CANDIDATE EVENTS: 93
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8031.tsv
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8032.tsv
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8033.tsv
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8034.tsv
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8035.tsv
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8036.tsv
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8037.tsv
# LOADING FILE:  ../../output202210/BEHAVIORAD/extraction-8038.tsv
# 112 total annotation for target terms
# Length of Sequence Dictionary: 112
# CANDIDATE EVENTS: 112
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8050.tsv
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8051.tsv
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8052.tsv
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8053.tsv
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8054.tsv
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8055.tsv
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8056.tsv
# LOADING FILE:  ../../output202210/MISOPHONIA/extraction-8057.tsv
# 0 total annotation for target terms
# Length of Sequence Dictionary: 0
# CANDIDATE EVENTS: 0
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/IDU/extraction-8071.tsv
# LOADING FILE:  ../../output202210/IDU/extraction-8072.tsv
# LOADING FILE:  ../../output202210/IDU/extraction-8073.tsv
# LOADING FILE:  ../../output202210/IDU/extraction-8074.tsv
# LOADING FILE:  ../../output202210/IDU/extraction-8075.tsv
# LOADING FILE:  ../../output202210/IDU/extraction-8076.tsv
# LOADING FILE:  ../../output202210/IDU/extraction-8077.tsv
# LOADING FILE:  ../../output202210/IDU/extraction-8078.tsv
# 153 total annotation for target terms
# Length of Sequence Dictionary: 153
# CANDIDATE EVENTS: 153
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8141.tsv
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8142.tsv
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8143.tsv
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8144.tsv
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8145.tsv
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8146.tsv
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8147.tsv
# LOADING FILE:  ../../output202210/JOBINSTABLE/extraction-8148.tsv
# 1149 total annotation for target terms
# Length of Sequence Dictionary: 1149
# CANDIDATE EVENTS: 1149
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8226.tsv
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8227.tsv
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8228.tsv
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8229.tsv
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8230.tsv
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8231.tsv
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8232.tsv
# LOADING FILE:  ../../output202210/JUSTICE/extraction-8233.tsv
# 398 total annotation for target terms
# Length of Sequence Dictionary: 398
# CANDIDATE EVENTS: 398
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8107.tsv
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8108.tsv
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8109.tsv
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8110.tsv
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8111.tsv
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8112.tsv
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8113.tsv
# LOADING FILE:  ../../output202210/LIVESALONE/extraction-8114.tsv
# 1009 total annotation for target terms
# Length of Sequence Dictionary: 1009
# CANDIDATE EVENTS: 1009
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8090.tsv
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8091.tsv
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8092.tsv
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8093.tsv
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8094.tsv
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8095.tsv
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8096.tsv
# LOADING FILE:  ../../output202210/LONELINESS/extraction-8097.tsv
# 272 total annotation for target terms
# Length of Sequence Dictionary: 272
# CANDIDATE EVENTS: 272
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8248.tsv
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8249.tsv
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8250.tsv
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8251.tsv
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8252.tsv
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8253.tsv
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8254.tsv
# LOADING FILE:  ../../output202210/SOCIALCONNECT/extraction-8255.tsv
# 542 total annotation for target terms
# Length of Sequence Dictionary: 542
# CANDIDATE EVENTS: 542
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8164.tsv
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8165.tsv
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8166.tsv
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8167.tsv
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8168.tsv
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8169.tsv
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8170.tsv
# LOADING FILE:  ../../output202210/STRAUMA/extraction-8171.tsv
# 2053 total annotation for target terms
# Length of Sequence Dictionary: 2053
# CANDIDATE EVENTS: 2053
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/HOUSING/extraction-8279.tsv
# LOADING FILE:  ../../output202210/HOUSING/extraction-8280.tsv
# LOADING FILE:  ../../output202210/HOUSING/extraction-8281.tsv
# LOADING FILE:  ../../output202210/HOUSING/extraction-8282.tsv
# LOADING FILE:  ../../output202210/HOUSING/extraction-8283.tsv
# LOADING FILE:  ../../output202210/HOUSING/extraction-8284.tsv
# LOADING FILE:  ../../output202210/HOUSING/extraction-8285.tsv
# LOADING FILE:  ../../output202210/HOUSING/extraction-8286.tsv
# 8775 total annotation for target terms
# Length of Sequence Dictionary: 8775
# CANDIDATE EVENTS: 8775
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/DETOX/extraction-8366.tsv
# LOADING FILE:  ../../output202210/DETOX/extraction-8367.tsv
# LOADING FILE:  ../../output202210/DETOX/extraction-8368.tsv
# LOADING FILE:  ../../output202210/DETOX/extraction-8369.tsv
# LOADING FILE:  ../../output202210/DETOX/extraction-8370.tsv
# LOADING FILE:  ../../output202210/DETOX/extraction-8371.tsv
# LOADING FILE:  ../../output202210/DETOX/extraction-8372.tsv
# LOADING FILE:  ../../output202210/DETOX/extraction-8373.tsv
# 3294 total annotation for target terms
# Length of Sequence Dictionary: 3294
# CANDIDATE EVENTS: 3294
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9009.tsv
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9010.tsv
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9011.tsv
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9012.tsv
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9013.tsv
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9014.tsv
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9015.tsv
# LOADING FILE:  ../../output202210/FOODINSECURE/extraction-9016.tsv
# 345 total annotation for target terms
# Length of Sequence Dictionary: 345
# CANDIDATE EVENTS: 345
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8398.tsv
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8399.tsv
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8400.tsv
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8401.tsv
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8402.tsv
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8403.tsv
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8404.tsv
# LOADING FILE:  ../../output202210/LETHALMEANS/extraction-8405.tsv
# 322 total annotation for target terms
# Length of Sequence Dictionary: 322
# CANDIDATE EVENTS: 322
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/COVID/extraction-8430.tsv
# LOADING FILE:  ../../output202210/COVID/extraction-8431.tsv
# LOADING FILE:  ../../output202210/COVID/extraction-8432.tsv
# LOADING FILE:  ../../output202210/COVID/extraction-8434.tsv
# LOADING FILE:  ../../output202210/COVID/extraction-8435.tsv
# LOADING FILE:  ../../output202210/COVID/extraction-8436.tsv
# LOADING FILE:  ../../output202210/COVID/extraction-8437.tsv
# LOADING FILE:  ../../output202210/COVID/extraction-8438.tsv
# 21669 total annotation for target terms
# Length of Sequence Dictionary: 21669
# CANDIDATE EVENTS: 21669
# Total notes:  343079
# NOTES: 343079
# LOADING FILE:  ../../output202210/ADL/extraction-9133.tsv
# LOADING FILE:  ../../output202210/ADL/extraction-9134.tsv
# LOADING FILE:  ../../output202210/ADL/extraction-9135.tsv
# LOADING FILE:  ../../output202210/ADL/extraction-9136.tsv
# LOADING FILE:  ../../output202210/ADL/extraction-9137.tsv
# LOADING FILE:  ../../output202210/ADL/extraction-9138.tsv
# LOADING FILE:  ../../output202210/ADL/extraction-9139.tsv
# LOADING FILE:  ../../output202210/ADL/extraction-9140.tsv
# 259 total annotation for target terms
# Length of Sequence Dictionary: 259
# CANDIDATE EVENTS: 259

# %%
# Step 4
# !bash ../src/step4/step4.sh
# Out:
# Processing: ../../output202210/XYLA/linkedAnts.txt
# WROTE POS NEG NA FILES
# Processing: ../../output202210/A2AG/linkedAnts.txt
# WROTE POS NEG NA FILES
# Processing: ../../output202210/PDMP/linkedAnts.txt
# WROTE POS NEG NA FILES
# Processing: ../../output202210/CAFFINEDO/linkedAnts.txt
# WROTE POS NEG NA FILES
# Processing: ../../output202210/BTRAITS/linkedAnts.txt
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'PPAIN', 'DOT', 'DOT', 'NEGEX', 'DOT', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'HX', 'PPAIN', 'CAPACITY', 'CAPACITY', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CONNECT', 'CAPACITY', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CAPACITY', 'PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'DOT', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'HX', 'HX', 'HX', 'CAPACITY', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/BDD/linkedAnts.txt
# WROTE POS NEG NA FILES
# Processing: ../../output202210/GAMINGDO/linkedAnts.txt
# WROTE POS NEG NA FILES
# Processing: ../../output202210/GAMBLINGDO/linkedAnts.txt
# CAPACITY ['NEGEX', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/BEHAVIORAD/linkedAnts.txt
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'DOT', 'FAM', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'CAPACITY', 'HX', 'NEGEX', 'CAPACITY', 'DOT', 'NEGEX', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'FAM', 'NEGEX', 'DOT', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/MISOPHONIA/linkedAnts.txt
# WROTE POS NEG NA FILES
# Processing: ../../output202210/IDU/linkedAnts.txt
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CONNECT', 'HX', 'HX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/JOBINSTABLE/linkedAnts.txt
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'HOPELESS']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'CONNECT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN', 'CAPACITY', 'CONNECT']
# CAPACITY ['NEGEX', 'DOT', 'DOT', 'CAPACITY', 'CONNECT']
# CAPACITY ['HX', 'HX', 'JUSTICE', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'FAM', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN', 'CAPACITY', 'HOUSING']
# CAPACITY ['JUSTICE', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'DOT', 'HX', 'CONNECT', 'DOT', 'NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'CAPACITY', 'HX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['JUSTICE', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN', 'CAPACITY', 'CONNECT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'HOUSING', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['PPAIN', 'CAPACITY', 'CONNECT', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'FAM', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN', 'CAPACITY', 'HOUSING']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'CONNECT']
# CAPACITY ['HOPELESS', 'PPAIN', 'PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'DOT', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'HX', 'HX', 'CAPACITY', 'HOUSING']
# CAPACITY ['DOT', 'DOT', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['CONNECT', 'DOT', 'DOT', 'FAM', 'CAPACITY', 'DOT']
# CAPACITY ['FAM', 'HX', 'NEGEX', 'FAM', 'HX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'NEGEX', 'HX', 'NEGEX', 'NEGEX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'CONNECT']
# CAPACITY ['CAPACITY', 'NEGEX', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'DOT', 'NEGEX', 'CAPACITY', 'CONNECT']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'NEGEX', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'FAM', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN', 'CAPACITY', 'HOUSING']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'HOUSING']
# CAPACITY ['PPAIN', 'HX', 'HX', 'DOT', 'CAPACITY', 'HOUSING']
# CAPACITY ['NEGEX', 'NEGEX', 'NEGEX', 'PPAIN', 'CAPACITY', 'CAPACITY', 'HX']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/JUSTICE/linkedAnts.txt
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'NEGEX', 'CAPACITY', 'DOT', 'HX', 'CAPACITY', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'DOT', 'DOT', 'PPAIN', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/LIVESALONE/linkedAnts.txt
# CAPACITY ['CAPACITY', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'FAM', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'FAM', 'FAM', 'FAM', 'HX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['FAM', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'HX', 'NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'HX', 'FAM', 'HX', 'FAM', 'CAPACITY', 'HX', 'HX', 'DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'DOT', 'HX', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'PPAIN', 'DOT', 'DOT', 'HX', 'DOT', 'NEGEX', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'HX', 'DOT', 'DOT', 'HX', 'HX', 'FAM', 'HX', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['FAM', 'HX', 'FAM', 'FAM', 'HX', 'DOT', 'CAPACITY', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CONNECT']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'HX', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'HX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'HOUSING']
# CAPACITY ['FAM', 'HX', 'NEGEX', 'HX', 'DOT', 'HX', 'HX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/LONELINESS/linkedAnts.txt
# CAPACITY ['DOT', 'PPAIN', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'FAM', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CONNECT']
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'HX', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/SOCIALCONNECT/linkedAnts.txt
# CAPACITY ['DOT', 'PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['PPAIN', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['HOUSING', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'DOT', 'HX', 'HX', 'HX', 'CONNECT', 'FAM', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'PPAIN', 'DOT', 'PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CONNECT', 'CAPACITY', 'HX']
# CAPACITY ['PPAIN', 'CAPACITY', 'CONNECT']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'PPAIN', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'NEGEX', 'FAM', 'HX', 'CAPACITY', 'HX', 'CAPACITY', 'HOPELESS']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'HX', 'HOPELESS', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'PPAIN', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['CONNECT', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['PPAIN', 'PPAIN', 'PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HOUSING']
# CAPACITY ['HX', 'DOT', 'NEGEX', 'HX', 'DOT', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/STRAUMA/linkedAnts.txt
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'HX', 'HX', 'FAM', 'HX', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'HX', 'DOT', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'HX', 'HX', 'FAM', 'HX', 'NEGEX', 'HX', 'DOT', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'FAM', 'HX', 'FAM', 'FAM', 'PPAIN', 'CAPACITY', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'FAM', 'HX', 'FAM', 'FAM', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'HX', 'HX', 'FAM', 'HX', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'HX', 'HX', 'FAM', 'HX', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'CAPACITY', 'PPAIN']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/HOUSING/linkedAnts.txt
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'HX', 'CAPACITY', 'HX', 'CAPACITY', 'JUSTICE']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'DOT', 'PPAIN', 'FAM', 'CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['PPAIN', 'HX', 'CAPACITY', 'GAMBLINGDO']
# CAPACITY ['NEGEX', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CONNECT', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HOPELESS', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'DOT', 'JUSTICE', 'DOT', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'NEGEX', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'NEGEX', 'NEGEX', 'DOT', 'HX', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HOPELESS', 'CAPACITY', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'NEGEX', 'NEGEX', 'NEGEX', 'CONNECT', 'NEGEX', 'CONNECT', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CONNECT', 'PPAIN', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'PPAIN', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['FAM', 'DOT', 'CONNECT', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'JUSTICE']
# CAPACITY ['CAPACITY', 'PPAIN', 'DOT', 'PPAIN', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'HOPELESS', 'DOT', 'HX', 'PPAIN', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'DOT', 'HX', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CONNECT', 'CONNECT', 'PPAIN', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'NEGEX', 'NEGEX', 'NEGEX', 'CONNECT', 'NEGEX', 'CONNECT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'DOT', 'NEGEX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['FAM', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY', 'HOPELESS']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'HOPELESS', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'NEGEX', 'NEGEX', 'NEGEX', 'CONNECT', 'NEGEX', 'CONNECT', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['FAM', 'FAM', 'CAPACITY', 'HX']
# CAPACITY ['FAM', 'HX', 'CONNECT', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CONNECT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CONNECT', 'FAM', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'PPAIN', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'FAM', 'HX', 'CAPACITY', 'FAM', 'FAM', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'PPAIN', 'CAPACITY', 'DOT', 'PPAIN', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'DETOX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'PPAIN', 'PPAIN', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN', 'PPAIN', 'HX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'HX', 'HX', 'HX', 'CAPACITY', 'JOBINSTABLE']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CONNECT']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'NEGEX', 'NEGEX', 'NEGEX', 'CONNECT', 'NEGEX', 'CONNECT', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CONNECT', 'DOT', 'NEGEX', 'NEGEX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'HX', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CONNECT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HOPELESS', 'DOT', 'DOT', 'PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'DOT', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'DOT', 'DOT', 'NEGEX', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY', 'JUSTICE']
# CAPACITY ['FAM', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'HX', 'DOT', 'PPAIN', 'DOT', 'CONNECT', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'PPAIN', 'HX', 'CAPACITY', 'CONNECT']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'JOBINSTABLE']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'DOT', 'GAMBLINGDO', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'HX', 'CAPACITY', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'HX', 'FAM', 'CAPACITY', 'DOT']
# CAPACITY ['FAM', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'HOPELESS', 'PPAIN', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'DOT', 'DOT', 'CAPACITY', 'CONNECT']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'HOPELESS']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'JUSTICE', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'CAPACITY', 'HOPELESS']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'PPAIN', 'CAPACITY', 'PPAIN', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['PPAIN', 'DOT', 'DOT', 'DOT', 'PPAIN', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'DOT', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CONNECT']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'NEGEX', 'DOT', 'NEGEX', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'CAPACITY', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'DOT', 'HX', 'NEGEX', 'DOT', 'NEGEX', 'HX', 'DOT', 'HX', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CONNECT', 'FAM', 'DOT', 'FAM', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['PPAIN', 'HX', 'CAPACITY', 'GAMBLINGDO']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'HOPELESS']
# CAPACITY ['NEGEX', 'PPAIN', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['FAM', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['CONNECT', 'CONNECT', 'PPAIN', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'DOT', 'DOT', 'DOT', 'DOT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'PPAIN', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'PPAIN', 'CAPACITY', 'PPAIN', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DETOX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'PPAIN', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT', 'PPAIN', 'NEGEX', 'CAPACITY', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'DOT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'FAM', 'HX', 'FAM', 'HX', 'FAM', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'NEGEX', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'DOT', 'DOT', 'NEGEX', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['CONNECT', 'CAPACITY', 'HOPELESS']
# CAPACITY ['HX', 'DOT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DETOX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CONNECT', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['FAM', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/DETOX/linkedAnts.txt
# CAPACITY ['CAPACITY', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'HX', 'DOT', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['FAM', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'FAM', 'CONNECT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'DOT', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'HX', 'CONNECT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CONNECT', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'HX', 'HX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'HX', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'DOT', 'DOT', 'DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CONNECT', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'FAM', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CONNECT', 'CONNECT', 'DOT', 'CAPACITY', 'CONNECT']
# CAPACITY ['CAPACITY', 'CONNECT', 'CONNECT', 'DOT', 'CAPACITY', 'CONNECT']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'PPAIN', 'PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'PPAIN']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['FAM', 'BTRAITS', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'HX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'HX', 'HX', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'DOT', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'HX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CONNECT', 'DOT', 'HX', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'PPAIN', 'PPAIN', 'PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'PPAIN', 'HX', 'HX', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'PPAIN', 'DOT', 'CAPACITY', 'DOT']
# ...
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CONNECT', 'FAM', 'CAPACITY', 'DOT', 'HOPELESS', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'NEGEX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'HOPELESS']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'HX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'NEGEX', 'HX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'DOT', 'FAM', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX', 'NEGEX', 'HX', 'DOT', 'NEGEX', 'HOPELESS', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'NEGEX', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'DOT', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'DOT', 'HOPELESS', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'DOT', 'DOT', 'PPAIN', 'DOT', 'DOT', 'PPAIN', 'FAM', 'PPAIN', 'FAM', 'DOT', 'HX', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'HX', 'CAPACITY', 'DOT', 'CAPACITY', 'HX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'GAMBLINGDO', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['GAMBLINGDO', 'PPAIN', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['CONNECT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CONNECT', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'HX', 'CAPACITY', 'HX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'HX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'HX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'DOT', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'DOT', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'NEGEX', 'CAPACITY', 'PPAIN']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HOPELESS', 'CAPACITY', 'CAPACITY', 'DOT', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'BTRAITS']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'DOT', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'DOT', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'CAPACITY', 'HX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'HX', 'HX', 'HX', 'HX', 'CONNECT', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'HX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'PPAIN']
# CAPACITY ['CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'HX', 'NEGEX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'CAPACITY', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'HX', 'HX', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'HX', 'HX', 'HX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/LETHALMEANS/linkedAnts.txt
# CAPACITY ['PPAIN', 'CAPACITY', 'FAM', 'CAPACITY', 'DOT']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['CAPACITY', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'NEGEX', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'FAM', 'CAPACITY', 'HX', 'CAPACITY', 'HX', 'HX', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'CAPACITY', 'HX', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'FAM', 'CAPACITY', 'HX', 'CAPACITY', 'HX', 'HX', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['HX', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['PPAIN', 'FAM', 'CAPACITY', 'HX', 'CAPACITY', 'HX', 'HX', 'DOT', 'CAPACITY', 'CAPACITY', 'DOT']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT', 'DOT', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['FAM', 'CAPACITY', 'DOT']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'HX', 'NEGEX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'CONNECT', 'CAPACITY', 'NEGEX', 'CAPACITY', 'CAPACITY']
# CAPACITY ['NEGEX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['PPAIN', 'NEGEX', 'CAPACITY', 'DOT', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['NEGEX', 'NEGEX', 'HX', 'NEGEX', 'HX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'HX', 'DOT', 'CAPACITY', 'CAPACITY']
# CAPACITY ['DOT', 'NEGEX', 'DOT', 'NEGEX', 'CAPACITY', 'DOT']
# CAPACITY ['CAPACITY', 'CAPACITY', 'HX', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CONNECT', 'HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'DOT', 'CAPACITY', 'DOT', 'CAPACITY', 'DOT']
# CAPACITY ['NEGEX', 'HX', 'DOT', 'CAPACITY', 'CAPACITY', 'NEGEX']
# CAPACITY ['HX', 'HX', 'DOT', 'HX', 'HX', 'CAPACITY', 'HX', 'CAPACITY', 'NEGEX']
# CAPACITY ['HOPELESS', 'CAPACITY', 'NEGEX']
# CAPACITY ['CAPACITY', 'NEGEX', 'NEGEX', 'CAPACITY', 'CAPACITY', 'CAPACITY']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/FOODINSECURE/linkedAnts.txt
# CAPACITY ['DOT', 'NEGEX', 'NEGEX', 'CAPACITY', 'NEGEX']
# CAPACITY ['DOT', 'DOT', 'DOT', 'CAPACITY', 'DOT']
# WROTE POS NEG NA FILES
# Processing: ../../output202210/ADL/linkedAnts.txt
# CAPACITY ['SOCIALCONNECT', 'CAPACITY', 'CAPACITY', 'PPAIN']
# WROTE POS NEG NA FILES

# %%
# Step 5
# !bash ../src/step5/step5.sh
# Out:
# Filtering tagged templated text for XYLA
# Filtering tagged templated text for A2AG
# Filtering tagged templated text for PDMP
# Filtering tagged templated text for CAFFINEDO
# Filtering tagged templated text for BTRAITS
# Filtering tagged templated text for BDD
# Filtering tagged templated text for GAMINGDO
# Filtering tagged templated text for GAMBLINGDO
# Filtering tagged templated text for BEHAVIORAD
# Filtering tagged templated text for MISOPHONIA
# Filtering tagged templated text for IDU
# Filtering tagged templated text for JOBINSTABLE
# Filtering tagged templated text for JUSTICE
# Filtering tagged templated text for LIVESALONE
# Filtering tagged templated text for LONELINESS
# Filtering tagged templated text for SOCIALCONNECT
# Filtering tagged templated text for STRAUMA
# Filtering tagged templated text for HOUSING
# Filtering tagged templated text for DETOX
# Filtering tagged templated text for LETHALMEANS
# Filtering tagged templated text for FOODINSECURE
# Filtering tagged templated text for ADL
